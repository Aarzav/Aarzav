# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
df=pd.read_csv('lor.csv')

# %%
df
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
sns.relplot(x='Age',y='EstimatedSalary',data=df)

# %%
sns.relplot(x='Age',y='EstimatedSalary',data=df,hue='Gender')

# %%
sns.distplot(df["EstimatedSalary"])
# Out:
# C:\Users\91915\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='EstimatedSalary', ylabel='Density'>

# %%
sns.pairplot(df)#hue=.....

# %%
sns.rugplot(df['EstimatedSalary'])
# Out:
# <AxesSubplot:xlabel='EstimatedSalary'>

# %%
sns.countplot(x='Gender',data=df)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
plt.figure(figsize=(50,15))
plt.xticks(rotation=45)#give rotation to the value due to overlap
sns.barplot(x='Age',y='EstimatedSalary',data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='EstimatedSalary'>

# %% [markdown]
# hw : only 20 rows

# %%
sns.boxplot(x='Age',y='Gender',data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Gender'>

# %%
sns.violinplot(x='Age',y='Gender',data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Gender'>

# %%
sns.stripplot(x='Age',y='Gender',data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Gender'>

# %%
sns.swarmplot(x='Age',y='Gender',data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Gender'>

# %%
t=df.corr()#id inc...age dec correlation

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.lmplot(x='Age',y='EstimatedSalary',data=df)

# %%
df=pd.get_dummies(df,drop_first=True)

# %%
df
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0            1
# 1    15810944   35            20000          0            1
# 2    15668575   26            43000          0            0
# 3    15603246   27            57000          0            0
# 4    15804002   19            76000          0            1
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1            0
# 396  15706071   51            23000          1            1
# 397  15654296   50            20000          1            0
# 398  15755018   36            33000          0            1
# 399  15594041   49            36000          1            0
#
# [400 rows x 5 columns]

# %%
sns.catplot(x='Gender_Male',y='EstimatedSalary',data=df,kind="swarm",hue="Age")

# %%
sns.clustermap(df)
