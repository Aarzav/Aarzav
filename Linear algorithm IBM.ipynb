# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd


df = pd.read_csv ('Price.csv')
i = df[["Area (sqft)"]]
d= df[["Price ($)"]]
#d = df.iloc[:,1]

df.info()
i
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Area (sqft)  40 non-null     int64
#  1   Price ($)    40 non-null     int64
# dtypes: int64(2)
# memory usage: 768.0 bytes
#     Area (sqft)
# 0          2000
# 1          1600
# 2          1980
# 3          1840
# 4          1710
# 5          1550
# 6          1470
# 7          1710
# 8          1540
# 9          1620
# 10         1500
# 11         1720
# 12         1600
# 13         1700
# 14         1440
# 15         1520
# 16         1960
# 17         1700
# 18         1420
# 19         1520
# 20         1900
# 21         1640
# 22         1900
# 23         1860
# 24         1700
# 25         1590
# 26         1410
# 27         1770
# 28         1550
# 29         1600
# 30         1580
# 31         1760
# 32         1600
# 33         1790
# 34         1480
# 35         1500
# 36         1980
# 37         1710
# 38         1400
# 39         1590

# %%
d
# Out:
#     Price ($)
# 0       88600
# 1       71600
# 2       93300
# 3       84300
# 4       80600
# 5       75200
# 6       69700
# 7       82000
# 8       69400
# 9       78700
# 10      79600
# 11      82600
# 12      74500
# 13      83500
# 14      76300
# 15      74000
# 16      92890
# 17      79500
# 18      75600
# 19      70000
# 20      82600
# 21      73600
# 22      92100
# 23      84700
# 24      82600
# 25      75900
# 26      68700
# 27      84700
# 28      72400
# 29      76700
# 30      82600
# 31      83600
# 32      78500
# 33      84500
# 34      78500
# 35      72000
# 36      92990
# 37      81500
# 38      71300
# 39      72500

# %%
from sklearn.model_selection import train_test_split
#from sklearn.cross_validation import train_test_split
x_train, x_test, y_train, y_test = train_test_split (i, d, test_size = .10,random_state=2)
x_test
# Out:
#     Area (sqft)
# 27         1770
# 9          1620
# 14         1440
# 0          2000

# %%
from sklearn.linear_model import LinearRegression
lnr = LinearRegression()
lnr.fit (x_train, y_train ) 

predicted_y = lnr.predict(x_test)
print("predicted y records:")
print(predicted_y)
# Out:
# predicted y records:
# [[83363.10792132]
#  [77729.34396598]
#  [70968.82721956]
#  [92001.54598618]]

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from math import sqrt
print("RMSE is:-")

print('Mean Absolute Error(MAE):', mean_absolute_error(y_test, predicted_y))
print('Mean Squared Error(MSE):', mean_squared_error(y_test, predicted_y))
print('Root Mean Squared Error(RMSE):', np.sqrt(mean_squared_error(y_test, predicted_y)))
# Out:
# RMSE is:-
# Mean Absolute Error(MAE): 2760.0667198298725
# Mean Squared Error(MSE): 10680342.969342817
# Root Mean Squared Error(RMSE): 3268.079400709661

# %%
plt.scatter(x_test, y_test, color = 'red')
plt.plot(x_test, predicted_y, color = 'green')
plt.title ('Results ')
plt.xlabel('Area of Flats')
plt.ylabel('Price')
plt.show()

# %%
#explain equation now y=mx+c
m=lnr.coef_
c=lnr.intercept_
print(m) #slope
print(c)  

y=m*1900+c  #Here i is x as defined above
print(y)


lnr.predict([[1900]])
# Out:
# [[37.55842637]]
# [16884.69324827]
# [[88245.70334928]]
# array([[88245.70334928]])
