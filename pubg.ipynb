# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pubg=pd.read_csv('pubg.csv')
pubg
# Out:
#     Weapon Name              Weapon Type  Bullet Type  Damage  \
# 0         Groza            Assault Rifle         7.62      49
# 1           AKM            Assault Rifle         7.62      49
# 2          M762            Assault Rifle         7.62      47
# 3   MK47 Mutant            Assault Rifle         7.62      49
# 4        AUG A3            Assault Rifle         5.56      43
# 5        SCAR-L            Assault Rifle         5.56      43
# 6          M416            Assault Rifle         5.56      43
# 7         M16A4            Assault Rifle         5.56      43
# 8          G36C            Assault Rifle         5.56      43
# 9           OBZ            Assault Rifle         5.56      43
# 10         M249        Light Machine Gun         5.56      45
# 11        DP-28        Light Machine Gun         7.62      51
# 12       Vector           Submachine Gun         9.00      31
# 13          Uzi           Submachine Gun         9.00      26
# ...

# %%
pubg['Weapon Type'].unique()
# Out:
# array(['Assault Rifle', 'Light Machine Gun', 'Submachine Gun', 'Shotgun',
#        'Designed Marksman Rifle', 'Sniper Rifle', 'Pistol', 'Other',
#        'Melee'], dtype=object)

# %%
pubg['Bullet Type'].unique()
# Out:
# array([ 7.62,  5.56,  9.  ,  0.45, 12.  ,  0.3 ,   nan])

# %%
ar=pubg[pubg['Weapon Type']==('Assault Rifle')]

# %%
shotgun=pubg[pubg['Weapon Type']==('Shotgun')]

# %%
smg=pubg[pubg['Weapon Type']==('Submachine Gun')]

# %%
lmg=pubg[pubg['Weapon Type']==('Light Machine Gun')]

# %%
dmr=pubg[pubg['Weapon Type']==('Designed Marksman Rifle')]

# %%
pistol=pubg[pubg['Weapon Type']==('Pistol')]

# %%
sniper=pubg[pubg['Weapon Type']==('Sniper Rifle')]

# %%
melee=pubg[pubg['Weapon Type']==('Melee')]

# %%
plt.figure(figsize=(8,5))
plt.plot(ar['Weapon Name'],ar['Damage'])
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(smg['Weapon Name'],smg['Damage'])
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(lmg['Weapon Name'],lmg['Damage'])
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(shotgun['Weapon Name'],shotgun['Damage'])
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(dmr['Weapon Name'],dmr['Damage'])
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(melee['Weapon Name'],melee['Damage'])
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(pistol['Weapon Name'],pistol['Damage'])
plt.show()

# %%
sns.barplot(y='Bullet Type',x='Damage',data=pubg,hue='Weapon Type')
# Out:
# <AxesSubplot:xlabel='Damage', ylabel='Bullet Type'>
